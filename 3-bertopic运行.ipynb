# %% [markdown]
# # 导入必要的模块

# %%
import numpy as np
import pandas as pd
import re
import os
import traceback
import json
import math
from bertopic import BERTopic
from itertools import product
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import normalize
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage, fcluster
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import MaximalMarginalRelevance
from umap import UMAP
from hdbscan import HDBSCAN
from gensim.models.coherencemodel import CoherenceModel
import logging
from tqdm import tqdm

# %% [markdown]
# # 基本路径设置

# %%
CACHE_PATH = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/embedding/merged_embedding_results.json"  
CSV_PATH = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/embedding/processed_data.csv"
RESULT_CSV = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/bertopic_docs_topics.csv"
TERMS_CSV = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/bertopic_topic_terms.csv"
MODEL_DIR = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/model/bertopic_model"
OUTPUT_DIR = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_research"
EXPORT_PATH = "/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search.xlsx"

# %% [markdown]
# # 导入文本数据

# %% [markdown]
# ## documents

# %%
data = pd.read_csv(CSV_PATH)
data = data.dropna(subset=['content_cutted']).reset_index(drop=True)
data_embedding = data.copy(deep=True)

documents = data_embedding['content_cutted'].dropna()  # 去掉 NaN
documents = documents[documents.str.strip() != ""]  # 去掉空字符串
documents = documents.tolist()

print(f"有效内容数量: {len(documents)}")
# Out:
# 有效内容数量: 3229

# %% [markdown]
# ## X

# %%
assert isinstance(documents, list), "documents 应为 list[str]，请先加载好。"

def is_numeric_vector(vec):
    if not isinstance(vec, list) or not vec:
        return False
    for x in vec:
        if not isinstance(x, (int, float)):
            return False
        fx = float(x)
        if math.isnan(fx) or math.isinf(fx):
            return False
    return True

cache = {}
invalid_entries = []  

with open(CACHE_PATH, "r", encoding="utf-8") as f:
    for line in f:
        try:
            # 逐行解析每个 JSON 对象
            obj = json.loads(line.strip())  # 读取并去掉空格
            # 假设每行的 JSON 对象包含 key 和对应的向量
            key = str(obj["key"])  # 获取 key
            embedding = obj.get("embedding")
            cache[key] = embedding
        except json.JSONDecodeError as e:
            invalid_entries.append({"key": line.strip(), "reason": f"无法解析行，错误: {e}"})

valid_indices = []
texts = []
embeds = []

N = len(documents)
for i in range(N):
    key = str(i + 1)  # 将索引转为字符串
    vec = cache.get(key)  # 从缓存中获取该 key 对应的向量
    if is_numeric_vector(vec):  # 如果该向量有效
        valid_indices.append(i)
        texts.append(documents[i])  # 保留文本
        embeds.append(vec)  # 保留嵌入向量
    else:
        invalid_entries.append({"key": key, "reason": "无效向量"})

# 输出有效条目数量
print(f"可用条目：{len(valid_indices)}/{N}（其余因缺失/无效向量被过滤）")

X = np.array(embeds, dtype=float)

# 输出不可用条目的详细信息
if invalid_entries:
    print("不可用条目详细信息：")
    for entry in invalid_entries:
        print(f"Key: {entry['key']}, 原因: {entry['reason']}")
else:
    print("没有发现不可用条目。")
# Out:
# 可用条目：3229/3229（其余因缺失/无效向量被过滤）
# 没有发现不可用条目。

# %% [markdown]
# ## 日志

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
# 抑制 BERTopic 和 HDBSCAN 的 INFO 级别日志
logging.getLogger('bertopic').setLevel(logging.WARNING)
logging.getLogger('hdbscan').setLevel(logging.WARNING)

# %% [markdown]
# ### 定义参数组合

# %%
param_grid = {
    'n_neighbors': [10, 15, 20, 25],
    'n_components': [5, 10, 15, 20],
    'min_cluster_size': [2, 3, 4, 5],
}


def generate_param_combinations(param_dict):
    import itertools
    keys = param_dict.keys()
    values = param_dict.values()
    combinations = [dict(zip(keys, p)) for p in itertools.product(*values)]
    return combinations

param_combinations = generate_param_combinations(param_grid)
logging.info(f"将运行 {len(param_combinations)} 种参数组合。")
# Out:
# 2025-09-25 20:10:41,172 - root - INFO - 将运行 64 种参数组合。

# %% [markdown]
# ### 辅助函数

# %%
def auto_threshold(merge_d):
    if merge_d.size < 2:
        return float(merge_d[-1] if merge_d.size else 0.0)
    jumps = (merge_d[1:] - merge_d[:-1]) / np.maximum(merge_d[:-1], 1e-9)
    k = int(np.argmax(jumps))
    th = float((merge_d[k] + merge_d[k+1]) / 2.0)
    lo, hi = np.percentile(merge_d, [50, 95])
    return float(np.clip(th, lo, hi))

def is_valid_token(w: str) -> bool:
    if not isinstance(w, str) or not w: return False
    if re.search(r"\d", w): return False
    if re.fullmatch(r"[\W_]+", w): return False
    return len(w) > 2

def cluster_metrics(X, labels, sample_cap=6000, seed=42):
    rng = np.random.default_rng(seed)
    labels = np.asarray(labels, dtype=int)
    outlier_rate = float(np.mean(labels == -1))
    
    def cosine(u, v):
        du = np.linalg.norm(u); dv = np.linalg.norm(v)
        if du == 0 or dv == 0: return 0.0
        return float(np.dot(u, v) / (du * dv))
    sims = []
    sizes = []
    for c in np.unique(labels):
        if c < 0: continue
        idx = np.where(labels == c)[0]
        sizes.append(len(idx))
        if len(idx) >= 2:
            max_pairs = min(400, len(idx)*(len(idx)-1)//2)
            if max_pairs > 0:
                for _ in range(max_pairs):
                    try:
                        a, b = rng.choice(idx, size=2, replace=False)
                        sims.append(cosine(X[a], X[b]))
                    except ValueError:
                        break
    intra_mean = float(np.mean(sims)) if sims else float('nan')
    sil = float('nan')
    keep = np.where(labels >= 0)[0]
    if keep.size >= 20:
        if keep.size > sample_cap:
            keep = rng.choice(keep, size=sample_cap, replace=False)
        sil = silhouette_score(X[keep], labels[keep], metric="cosine")
    n_clusters = int(np.sum(np.unique(labels) >= 0))
    avg_size = float(np.mean(sizes)) if sizes else 0.0
    return intra_mean, sil, outlier_rate, n_clusters, avg_size

def calculate_coherence_robust(topic_model, topics, texts, dictionary):
    valid_topic_words = []
    topic_words_dict = topic_model.get_topics()
    for topic_id in topic_words_dict.keys():
        if topic_id == -1:
            continue
        raw_words = topic_model.get_topic(topic_id)
        topic_words_for_gensim = []
        for word, _ in raw_words:
            tokens = re.findall(r'\b[a-zA-Z]+\b', word.lower())
            for token in tokens:
                if token in dictionary.token2id:
                    topic_words_for_gensim.append(token)
        if topic_words_for_gensim:
            valid_topic_words.append(topic_words_for_gensim)
    if not valid_topic_words:
        logging.warning("没有生成任何有效主题，C_V 一致性为 0。")
        return 0.0
    try:
        coherence_model = CoherenceModel(
            topics=valid_topic_words,
            texts=texts,
            dictionary=dictionary,
            coherence='c_v'
        )
        return coherence_model.get_coherence()
    except Exception as e:
        logging.error(f"Gensim 计算 C_V 失败，错误信息：{e}")
        return 0.0

# %% [markdown]
# ### 辅助一致性计算

# %%
tokenized_docs = []
for doc in documents:
    words = re.findall(r'\b[a-zA-Z]+\b', doc.lower())
    tokenized_docs.append(words)
dictionary = Dictionary(tokenized_docs)
logging.info(f"Gensim 词典创建完成，包含 {len(dictionary)} 个词汇。")
valid_idx = np.arange(len(documents))
    
param_combinations = [dict(zip(param_grid.keys(), v)) for v in product(*param_grid.values())]
# Out:
# 2025-09-25 20:10:45,725 - gensim.corpora.dictionary - INFO - adding document #0 to Dictionary<0 unique tokens: []>
# 2025-09-25 20:10:45,852 - gensim.corpora.dictionary - INFO - built Dictionary<8824 unique tokens: ['add', 'administrative', 'aspect', 'assess', 'basis']...> from 3229 documents (total 358966 corpus positions)
# 2025-09-25 20:10:45,853 - gensim.utils - INFO - Dictionary lifecycle event {'msg': "built Dictionary<8824 unique tokens: ['add', 'administrative', 'aspect', 'assess', 'basis']...> from 3229 documents (total 358966 corpus positions)", 'datetime': '2025-09-25T20:10:45.853074', 'gensim': '4.3.3', 'python': '3.10.16 (main, Dec 11 2024, 10:22:29) [Clang 14.0.6 ]', 'platform': 'macOS-15.0.1-arm64-arm-64bit', 'event': 'created'}
# 2025-09-25 20:10:45,853 - root - INFO - Gensim 词典创建完成，包含 8824 个词汇。

# %%
results = []

SIM_THRESHOLD = 0.9 
ABSORB_THRESHOLD = 0.7
TOP_K = 30

for i, params in enumerate(tqdm(param_combinations, desc="正在进行参数组合训练")):
    try:
        logging.info(f"\n--- 开始第 {i+1}/{len(param_combinations)} 次训练，参数: {params} ---")
        
        # 1. 配置 BERTopic 模型
        umap_model = UMAP(
            n_neighbors=params['n_neighbors'],
            n_components=params['n_components'],
            min_dist=0.0,
            metric="cosine",
            random_state=42
        )
        hdbscan_model = HDBSCAN(
            min_cluster_size=params['min_cluster_size'],
            metric="euclidean",
            cluster_selection_method="leaf",
            prediction_data=True
        )
        vectorizer_model = CountVectorizer(
            ngram_range=(1, 2),
            min_df=2,
            max_df=0.9
        )
        representation_model = MaximalMarginalRelevance(diversity=0.0)
        
        topic_model = BERTopic(
            embedding_model=None,
            umap_model=umap_model,
            hdbscan_model=hdbscan_model,
            vectorizer_model=vectorizer_model,
            representation_model=representation_model,
            nr_topics="auto",
            calculate_probabilities=True,
            verbose=False
        )
        
        # 2. 训练 BERTopic 模型
        topics, probs = topic_model.fit_transform(documents, embeddings=X)
        topics = np.array(topics, dtype=int)
        
        # 3. 主题合并流程
        mask_in = topics >= 0
        topic_ids = np.unique(topics[mask_in])
        centroids, tid_list = [], []
        for tid in topic_ids:
            doc_idx = np.where(topics == tid)[0]
            if len(doc_idx) > 0:
                centroids.append(X[doc_idx].mean(axis=0))
                tid_list.append(int(tid))
        
        if not centroids:
            raise ValueError("No valid topics found for merging.")
            
        centroids = normalize(np.vstack(centroids))
        dist = pdist(centroids, metric="cosine")
        Z = linkage(dist, method="average")
        merge_d = Z[:, 2]
        
        # 相似度阈值来合并主题
        if SIM_THRESHOLD is None:
            distance_threshold = auto_threshold(merge_d)
        else:
            distance_threshold = float(1.0 - SIM_THRESHOLD)
        
        super_labels_topics = fcluster(Z, t=distance_threshold, criterion="distance")
        tid2super = {tid: sup for tid, sup in zip(tid_list, super_labels_topics)}
        topics_super = np.array([tid2super.get(tid, -1) for tid in topics])
        n_super = len(np.unique(topics_super))
        
        # 4. 离群点吸收
        super_ids = sorted(np.unique(super_labels_topics))
        super_centroids = []
        for sup in super_ids:
            member_tids = [tid for tid, s in tid2super.items() if s == sup]
            member_doc_idx = np.where(np.isin(topics, member_tids))[0]
            if len(member_doc_idx) > 0:
                super_centroids.append(X[member_doc_idx].mean(axis=0))
        
        if super_centroids:
            super_centroids = normalize(np.vstack(super_centroids))
            def cosine_sim_rows(A, b):
                b = b / (np.linalg.norm(b) + 1e-12)
                return A.dot(b)

            # 处理遗漏数据
            out_idx = np.where(topics_super == -1)[0]
            if out_idx.size:
                sims = np.vstack([cosine_sim_rows(super_centroids, X[i]) for i in out_idx])
                best_sup = np.argmax(sims, axis=1)
                best_val = sims[np.arange(sims.shape[0]), best_sup]
                absorb_mask = best_val >= ABSORB_THRESHOLD
                topics_super[out_idx[absorb_mask]] = np.array([super_ids[j] for j in best_sup[absorb_mask]], dtype=int)
                logging.info(f"吸收离群点：候选 {out_idx.size} 篇 → 吸收 {absorb_mask.sum()} 篇（阈值={ABSORB_THRESHOLD:.2f}）")

        # 5. 生成合并后超主题的可读标签
        topic_dict = topic_model.get_topics()
        df_topic_info = topic_model.get_topic_info().set_index("Topic")
        super_id_to_words = {}
        for sup in super_ids:
            member_tids = [tid for tid, s in tid2super.items() if s == sup]
            words_pool = []
            for tid in member_tids:
                pairs = topic_dict.get(int(tid), [])
                words_pool.extend([w for (w, s) in pairs if is_valid_token(w)])
            if words_pool:
                vc = pd.Series(words_pool).value_counts()
                super_id_to_words[sup] = ", ".join(vc.index[:TOP_K].tolist())
            else:
                names = []
                for tid in member_tids:
                    if tid in df_topic_info.index:
                        nm = str(df_topic_info.loc[tid, "Name"])
                        names.append(nm.split("_", 1)[-1] if "_" in nm else nm)
                super_id_to_words[sup] = " | ".join(names[:TOP_K]) if names else f"SuperTopic {sup}"

        # 6. 计算指标和 C_V 一致性
        m_before = cluster_metrics(X, topics)
        m_after = cluster_metrics(X, topics_super)
        cv_coherence = calculate_coherence_robust(topic_model, topics, tokenized_docs, dictionary)

        # 7. 将结果写回原始行并导出
        current_data = pd.read_csv(CSV_PATH)
        labels_full = np.full(len(documents), -1, dtype=int)
        labels_full[valid_idx] = topics_super
        label_text = pd.Series(labels_full).map(super_id_to_words).fillna("<No keywords>")

        current_data["hc_topic_label"] = labels_full
        current_data["hc_topic_label_text"] = label_text

        # 动态生成文件名
        file_name = f"result_n_comp_{params['n_components']}_msize_{params['min_cluster_size']}_neig_{params['n_neighbors']}.xlsx"
        export_path = os.path.join(OUTPUT_DIR, file_name)

        try:
            current_data.to_excel(export_path, index=False)
            logging.info(f"已导出文档和超主题结果：{export_path}")
        except Exception as e:
            logging.error(f"导出失败，错误：{e}")

        # 8. 存储结果到汇总列表
        result = {
            'n_neighbors': params['n_neighbors'],
            'n_components': params['n_components'],
            'min_cluster_size': params['min_cluster_size'],
            'num_original_topics': len(topic_ids),
            'num_merged_topics': n_super,
            'cv_coherence': cv_coherence,
            'intra_mean_before': m_before[0],
            'silhouette_before': m_before[1],
            'outlier_rate_before': m_before[2],
            'intra_mean_after': m_after[0],
            'silhouette_after': m_after[1],
            'outlier_rate_after': m_after[2]
        }
        results.append(result)
        
        logging.info(f"本次训练完成。原主题数: {result['num_original_topics']}，合并后超主题数: {result['num_merged_topics']}，C_V 一致性: {result['cv_coherence']:.4f}")
        logging.info(f"指标：轮廓系数 (合并前/后): {result['silhouette_before']:.4f}/{result['silhouette_after']:.4f}, 离群率: {result['outlier_rate_after']:.4f}")

    except Exception as e:
        logging.error(f"训练失败，参数组合 {params}。错误信息：{e}")
        continue
# Out:
# 正在进行参数组合训练:   0%|          | 0/64 [00:00<?, ?it/s]2025-09-25 20:10:52,667 - root - INFO -
# --- 开始第 1/64 次训练，参数: {'n_neighbors': 10, 'n_components': 5, 'min_cluster_size': 2} ---
# 2025-09-25 20:11:32,836 - root - INFO - 吸收离群点：候选 686 篇 → 吸收 670 篇（阈值=0.70）
# 2025-09-25 20:11:34,493 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:11:38,465 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:11:38,468 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:11:38,474 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:11:39,397 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:11:39,617 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:11:39,825 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:11:40,062 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:11:40,209 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:11:40,253 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:11:40,311 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:11:40,520 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:11:40,599 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:11:40,702 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:11:40,920 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:11:40,935 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:11:41,050 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:11:43,069 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:11:43,154 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:11:44,972 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:11:44,973 - root - INFO - 本次训练完成。原主题数: 197，合并后超主题数: 179，C_V 一致性: 0.6072
# 2025-09-25 20:11:44,973 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3616/0.3488, 离群率: 0.0050
# 正在进行参数组合训练:   2%|▏         | 1/64 [00:52<54:55, 52.31s/it]2025-09-25 20:11:44,974 - root - INFO -
# --- 开始第 2/64 次训练，参数: {'n_neighbors': 10, 'n_components': 5, 'min_cluster_size': 3} ---
# 2025-09-25 20:12:18,786 - root - INFO - 吸收离群点：候选 580 篇 → 吸收 564 篇（阈值=0.70）
# 2025-09-25 20:12:20,441 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:12:24,108 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:12:24,110 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:12:24,115 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:12:24,707 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:12:24,961 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:12:25,142 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:12:25,318 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:12:25,447 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:12:25,501 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:12:25,525 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:12:25,743 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:12:25,801 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:12:25,898 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:12:26,043 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:12:26,097 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:12:26,155 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:12:27,997 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:12:28,067 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:12:28,898 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:12:28,898 - root - INFO - 本次训练完成。原主题数: 153，合并后超主题数: 139，C_V 一致性: 0.6256
# 2025-09-25 20:12:28,899 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3404/0.3378, 离群率: 0.0050
# 正在进行参数组合训练:   3%|▎         | 2/64 [01:36<48:57, 47.38s/it]2025-09-25 20:12:28,899 - root - INFO -
# --- 开始第 3/64 次训练，参数: {'n_neighbors': 10, 'n_components': 5, 'min_cluster_size': 4} ---
# 2025-09-25 20:13:01,080 - root - INFO - 吸收离群点：候选 527 篇 → 吸收 513 篇（阈值=0.70）
# 2025-09-25 20:13:02,729 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:13:06,545 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:13:06,548 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:13:06,553 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:13:07,286 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:13:07,513 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:13:07,690 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:13:07,871 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:13:08,015 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:13:08,022 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:13:08,032 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:13:08,283 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:13:08,378 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:13:08,404 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:13:08,584 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:13:08,590 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:13:08,698 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:13:10,225 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:13:10,278 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:13:11,368 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:13:11,368 - root - INFO - 本次训练完成。原主题数: 138，合并后超主题数: 124，C_V 一致性: 0.6362
# 2025-09-25 20:13:11,368 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3333/0.3374, 离群率: 0.0043
# 正在进行参数组合训练:   5%|▍         | 3/64 [02:18<45:53, 45.14s/it]2025-09-25 20:13:11,369 - root - INFO -
# --- 开始第 4/64 次训练，参数: {'n_neighbors': 10, 'n_components': 5, 'min_cluster_size': 5} ---
# 2025-09-25 20:13:42,508 - root - INFO - 吸收离群点：候选 433 篇 → 吸收 422 篇（阈值=0.70）
# 2025-09-25 20:13:44,226 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:13:48,045 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:13:48,048 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:13:48,055 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:13:48,607 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:13:48,746 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:13:48,932 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:13:49,098 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:13:49,228 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:13:49,243 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:13:49,282 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:13:49,461 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:13:49,507 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:13:49,610 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:13:49,715 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:13:49,766 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:13:49,849 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:13:51,266 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:13:51,313 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:13:51,968 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:13:51,969 - root - INFO - 本次训练完成。原主题数: 124，合并后超主题数: 110，C_V 一致性: 0.6388
# 2025-09-25 20:13:51,969 - root - INFO - 指标：轮廓系数 (合并前/后): 0.2982/0.3167, 离群率: 0.0034
# 正在进行参数组合训练:   6%|▋         | 4/64 [02:59<43:20, 43.35s/it]2025-09-25 20:13:51,969 - root - INFO -
# --- 开始第 5/64 次训练，参数: {'n_neighbors': 10, 'n_components': 10, 'min_cluster_size': 2} ---
# 2025-09-25 20:14:32,634 - root - INFO - 吸收离群点：候选 774 篇 → 吸收 762 篇（阈值=0.70）
# 2025-09-25 20:14:34,275 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:14:38,100 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:14:38,103 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:14:38,115 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:14:38,772 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:14:39,040 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:14:39,247 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:14:39,449 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:14:39,630 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:14:39,637 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:14:39,646 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:14:39,886 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:14:39,993 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:14:40,094 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:14:40,206 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:14:40,304 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:14:40,382 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:14:42,316 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:14:42,384 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:14:43,826 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:14:43,827 - root - INFO - 本次训练完成。原主题数: 190，合并后超主题数: 172，C_V 一致性: 0.6134
# 2025-09-25 20:14:43,827 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3658/0.3566, 离群率: 0.0037
# 正在进行参数组合训练:   8%|▊         | 5/64 [03:51<45:38, 46.42s/it]2025-09-25 20:14:43,827 - root - INFO -
# --- 开始第 6/64 次训练，参数: {'n_neighbors': 10, 'n_components': 10, 'min_cluster_size': 3} ---
# 2025-09-25 20:15:18,110 - root - INFO - 吸收离群点：候选 536 篇 → 吸收 525 篇（阈值=0.70）
# 2025-09-25 20:15:19,683 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:15:23,492 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:15:23,495 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:15:23,500 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:15:24,189 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:15:24,313 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:15:24,522 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:15:24,658 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:15:24,879 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:15:24,886 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:15:24,950 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:15:25,123 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:15:25,168 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:15:25,325 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:15:25,441 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:15:25,504 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:15:25,533 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:15:27,417 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:15:27,473 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:15:28,329 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:15:28,330 - root - INFO - 本次训练完成。原主题数: 157，合并后超主题数: 143，C_V 一致性: 0.6266
# 2025-09-25 20:15:28,330 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3002/0.2942, 离群率: 0.0034
# 正在进行参数组合训练:   9%|▉         | 6/64 [04:35<44:14, 45.77s/it]2025-09-25 20:15:28,330 - root - INFO -
# --- 开始第 7/64 次训练，参数: {'n_neighbors': 10, 'n_components': 10, 'min_cluster_size': 4} ---
# 2025-09-25 20:16:00,647 - root - INFO - 吸收离群点：候选 489 篇 → 吸收 475 篇（阈值=0.70）
# 2025-09-25 20:16:02,303 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:16:06,026 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:16:06,028 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:16:06,034 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:16:06,607 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:16:06,793 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:16:06,993 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:16:07,196 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:16:07,332 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:16:07,338 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:16:07,351 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:16:07,591 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:16:07,601 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:16:07,733 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:16:07,839 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:16:07,914 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:16:07,981 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:16:09,608 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:16:09,660 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:16:10,440 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:16:10,440 - root - INFO - 本次训练完成。原主题数: 146，合并后超主题数: 130，C_V 一致性: 0.6316
# 2025-09-25 20:16:10,441 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3092/0.3195, 离群率: 0.0043
# 正在进行参数组合训练:  11%|█         | 7/64 [05:17<42:20, 44.57s/it]2025-09-25 20:16:10,441 - root - INFO -
# --- 开始第 8/64 次训练，参数: {'n_neighbors': 10, 'n_components': 10, 'min_cluster_size': 5} ---
# 2025-09-25 20:16:41,435 - root - INFO - 吸收离群点：候选 510 篇 → 吸收 486 篇（阈值=0.70）
# 2025-09-25 20:16:43,104 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:16:46,798 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:16:46,801 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:16:46,806 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:16:47,319 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:16:47,517 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:16:47,707 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:16:47,825 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:16:47,984 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:16:48,020 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:16:48,024 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:16:48,252 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:16:48,266 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:16:48,353 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:16:48,539 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:16:48,568 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:16:48,588 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:16:50,055 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:16:50,098 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:16:51,081 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:16:51,082 - root - INFO - 本次训练完成。原主题数: 120，合并后超主题数: 105，C_V 一致性: 0.6359
# 2025-09-25 20:16:51,082 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3005/0.3193, 离群率: 0.0074
# 正在进行参数组合训练:  12%|█▎        | 8/64 [05:58<40:25, 43.32s/it]2025-09-25 20:16:51,082 - root - INFO -
# --- 开始第 9/64 次训练，参数: {'n_neighbors': 10, 'n_components': 15, 'min_cluster_size': 2} ---
# 2025-09-25 20:17:31,864 - root - INFO - 吸收离群点：候选 736 篇 → 吸收 724 篇（阈值=0.70）
# 2025-09-25 20:17:33,427 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:17:37,180 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:17:37,182 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:17:37,188 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:17:37,885 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:17:38,149 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:17:38,411 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:17:38,592 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:17:38,798 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:17:38,810 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:17:38,818 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:17:39,109 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:17:39,143 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:17:39,339 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:17:39,401 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:17:39,557 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:17:39,673 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:17:41,751 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:17:41,825 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:17:43,335 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:17:43,336 - root - INFO - 本次训练完成。原主题数: 199，合并后超主题数: 174，C_V 一致性: 0.6203
# 2025-09-25 20:17:43,336 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3474/0.3415, 离群率: 0.0037
# 正在进行参数组合训练:  14%|█▍        | 9/64 [06:50<42:16, 46.11s/it]2025-09-25 20:17:43,336 - root - INFO -
# --- 开始第 10/64 次训练，参数: {'n_neighbors': 10, 'n_components': 15, 'min_cluster_size': 3} ---
# 2025-09-25 20:18:18,812 - root - INFO - 吸收离群点：候选 630 篇 → 吸收 619 篇（阈值=0.70）
# 2025-09-25 20:18:20,491 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:18:24,279 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:18:24,281 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:18:24,287 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:18:24,936 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:18:25,196 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:18:25,442 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:18:25,580 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:18:25,801 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:18:25,817 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:18:25,822 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:18:26,103 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:18:26,114 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:18:26,285 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:18:26,419 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:18:26,448 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:18:26,564 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:18:28,517 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:18:28,577 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:18:29,804 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:18:29,804 - root - INFO - 本次训练完成。原主题数: 159，合并后超主题数: 140，C_V 一致性: 0.6297
# 2025-09-25 20:18:29,804 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3550/0.3453, 离群率: 0.0034
# 正在进行参数组合训练:  16%|█▌        | 10/64 [07:37<41:36, 46.22s/it]2025-09-25 20:18:29,805 - root - INFO -
# --- 开始第 11/64 次训练，参数: {'n_neighbors': 10, 'n_components': 15, 'min_cluster_size': 4} ---
# 2025-09-25 20:19:02,410 - root - INFO - 吸收离群点：候选 614 篇 → 吸收 595 篇（阈值=0.70）
# 2025-09-25 20:19:03,989 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:19:07,905 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:19:07,908 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:19:07,913 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:19:08,573 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:19:08,816 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:19:09,007 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:19:09,228 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:19:09,369 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:19:09,379 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:19:09,403 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:19:09,652 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:19:09,695 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:19:09,830 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:19:09,989 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:19:10,040 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:19:10,083 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:19:11,871 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:19:11,925 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:19:12,693 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:19:12,693 - root - INFO - 本次训练完成。原主题数: 140，合并后超主题数: 123，C_V 一致性: 0.6336
# 2025-09-25 20:19:12,693 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3050/0.3123, 离群率: 0.0059
# 正在进行参数组合训练:  17%|█▋        | 11/64 [08:20<39:55, 45.20s/it]2025-09-25 20:19:12,694 - root - INFO -
# --- 开始第 12/64 次训练，参数: {'n_neighbors': 10, 'n_components': 15, 'min_cluster_size': 5} ---
# 2025-09-25 20:19:44,223 - root - INFO - 吸收离群点：候选 515 篇 → 吸收 496 篇（阈值=0.70）
# 2025-09-25 20:19:45,892 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:19:49,664 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:19:49,667 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:19:49,672 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:19:50,188 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:19:50,450 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:19:50,626 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:19:50,879 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:19:50,919 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:19:50,939 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:19:50,981 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:19:51,215 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:19:51,255 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:19:51,307 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:19:51,494 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:19:51,519 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:19:51,606 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:19:53,203 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:19:53,349 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:19:54,018 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:19:54,018 - root - INFO - 本次训练完成。原主题数: 122，合并后超主题数: 113，C_V 一致性: 0.6384
# 2025-09-25 20:19:54,019 - root - INFO - 指标：轮廓系数 (合并前/后): 0.2943/0.2934, 离群率: 0.0059
# 正在进行参数组合训练:  19%|█▉        | 12/64 [09:01<38:09, 44.02s/it]2025-09-25 20:19:54,019 - root - INFO -
# --- 开始第 13/64 次训练，参数: {'n_neighbors': 10, 'n_components': 20, 'min_cluster_size': 2} ---
# 2025-09-25 20:20:35,315 - root - INFO - 吸收离群点：候选 777 篇 → 吸收 766 篇（阈值=0.70）
# 2025-09-25 20:20:37,110 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:20:40,998 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:20:41,008 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:20:41,020 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:20:41,714 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:20:42,000 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:20:42,237 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:20:42,476 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:20:42,708 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:20:42,755 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:20:42,766 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:20:43,123 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:20:43,161 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:20:43,383 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:20:43,498 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:20:43,638 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:20:43,674 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:20:45,778 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:20:45,848 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:20:46,832 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:20:46,832 - root - INFO - 本次训练完成。原主题数: 177，合并后超主题数: 160，C_V 一致性: 0.6249
# 2025-09-25 20:20:46,833 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3422/0.3465, 离群率: 0.0034
# 正在进行参数组合训练:  20%|██        | 13/64 [09:54<39:40, 46.69s/it]2025-09-25 20:20:46,833 - root - INFO -
# --- 开始第 14/64 次训练，参数: {'n_neighbors': 10, 'n_components': 20, 'min_cluster_size': 3} ---
# 2025-09-25 20:21:21,244 - root - INFO - 吸收离群点：候选 568 篇 → 吸收 553 篇（阈值=0.70）
# 2025-09-25 20:21:22,853 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:21:26,592 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:21:26,594 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:21:26,600 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:21:27,191 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:21:27,459 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:21:27,642 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:21:27,865 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:21:28,000 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:21:28,021 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:21:28,028 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:21:28,310 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:21:28,316 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:21:28,458 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:21:28,627 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:21:28,685 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:21:28,736 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:21:30,594 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:21:30,654 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:21:31,854 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:21:31,854 - root - INFO - 本次训练完成。原主题数: 147，合并后超主题数: 136，C_V 一致性: 0.6228
# 2025-09-25 20:21:31,854 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3300/0.3272, 离群率: 0.0046
# 正在进行参数组合训练:  22%|██▏       | 14/64 [10:39<38:29, 46.18s/it]2025-09-25 20:21:31,855 - root - INFO -
# --- 开始第 15/64 次训练，参数: {'n_neighbors': 10, 'n_components': 20, 'min_cluster_size': 4} ---
# ...
# 2025-09-25 20:55:18,824 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:55:18,992 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:55:19,134 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:55:19,140 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:55:19,175 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:55:19,394 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:55:19,435 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:55:19,540 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:55:19,647 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:55:19,710 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:55:19,764 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:55:21,119 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:55:21,155 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:55:21,669 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:55:21,670 - root - INFO - 本次训练完成。原主题数: 98，合并后超主题数: 91，C_V 一致性: 0.6400
# 2025-09-25 20:55:21,670 - root - INFO - 指标：轮廓系数 (合并前/后): 0.2949/0.2797, 离群率: 0.0077
# 正在进行参数组合训练:  94%|█████████▍| 60/64 [44:29<02:53, 43.34s/it]2025-09-25 20:55:21,670 - root - INFO -
# --- 开始第 61/64 次训练，参数: {'n_neighbors': 25, 'n_components': 20, 'min_cluster_size': 2} ---
# 2025-09-25 20:56:01,129 - root - INFO - 吸收离群点：候选 1097 篇 → 吸收 1084 篇（阈值=0.70）
# 2025-09-25 20:56:02,655 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:56:06,424 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:56:06,427 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:56:06,432 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:56:07,241 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:56:07,525 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:56:07,730 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:56:07,929 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:56:08,112 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:56:08,138 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:56:08,175 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:56:08,498 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:56:08,526 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:56:08,685 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:56:08,934 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:56:08,972 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:56:09,063 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:56:11,101 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:56:11,172 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:56:12,553 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:56:12,553 - root - INFO - 本次训练完成。原主题数: 165，合并后超主题数: 144，C_V 一致性: 0.6255
# 2025-09-25 20:56:12,553 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3370/0.3360, 离群率: 0.0040
# 正在进行参数组合训练:  95%|█████████▌| 61/64 [45:19<02:16, 45.60s/it]2025-09-25 20:56:12,554 - root - INFO -
# --- 开始第 62/64 次训练，参数: {'n_neighbors': 25, 'n_components': 20, 'min_cluster_size': 3} ---
# 2025-09-25 20:56:46,245 - root - INFO - 吸收离群点：候选 806 篇 → 吸收 792 篇（阈值=0.70）
# 2025-09-25 20:56:47,833 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:56:51,612 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:56:51,615 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:56:51,620 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:56:52,364 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:56:52,532 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:56:52,774 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:56:52,891 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:56:53,135 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:56:53,159 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:56:53,189 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:56:53,439 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:56:53,507 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:56:53,687 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:56:53,827 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:56:53,840 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:56:53,952 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:56:55,772 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:56:55,825 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:56:56,575 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:56:56,575 - root - INFO - 本次训练完成。原主题数: 138，合并后超主题数: 124，C_V 一致性: 0.6337
# 2025-09-25 20:56:56,576 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3237/0.3281, 离群率: 0.0043
# 正在进行参数组合训练:  97%|█████████▋| 62/64 [46:03<01:30, 45.13s/it]2025-09-25 20:56:56,576 - root - INFO -
# --- 开始第 63/64 次训练，参数: {'n_neighbors': 25, 'n_components': 20, 'min_cluster_size': 4} ---
# 2025-09-25 20:57:28,945 - root - INFO - 吸收离群点：候选 660 篇 → 吸收 643 篇（阈值=0.70）
# 2025-09-25 20:57:30,596 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:57:34,379 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:57:34,382 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:57:34,388 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:57:35,038 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:57:35,218 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:57:35,420 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:57:35,612 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:57:35,733 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:57:35,776 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:57:35,823 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:57:36,058 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:57:36,085 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:57:36,193 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:57:36,364 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:57:36,414 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:57:36,527 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:57:38,014 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:57:38,067 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:57:39,104 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:57:39,104 - root - INFO - 本次训练完成。原主题数: 121，合并后超主题数: 113，C_V 一致性: 0.6374
# 2025-09-25 20:57:39,105 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3578/0.3394, 离群率: 0.0053
# 正在进行参数组合训练:  98%|█████████▊| 63/64 [46:46<00:44, 44.35s/it]2025-09-25 20:57:39,105 - root - INFO -
# --- 开始第 64/64 次训练，参数: {'n_neighbors': 25, 'n_components': 20, 'min_cluster_size': 5} ---
# 2025-09-25 20:58:10,931 - root - INFO - 吸收离群点：候选 631 篇 → 吸收 609 篇（阈值=0.70）
# 2025-09-25 20:58:12,557 - gensim.topic_coherence.probability_estimation - INFO - using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# 2025-09-25 20:58:16,335 - gensim.topic_coherence.text_analysis - INFO - 1 batches submitted to accumulate stats from 64 documents (2974 virtual)
# 2025-09-25 20:58:16,337 - gensim.topic_coherence.text_analysis - INFO - 2 batches submitted to accumulate stats from 128 documents (4038 virtual)
# 2025-09-25 20:58:16,343 - gensim.topic_coherence.text_analysis - INFO - 8 batches submitted to accumulate stats from 512 documents (-2575 virtual)
# 2025-09-25 20:58:16,925 - gensim.topic_coherence.text_analysis - INFO - 22 batches submitted to accumulate stats from 1408 documents (-24446 virtual)
# 2025-09-25 20:58:17,075 - gensim.topic_coherence.text_analysis - INFO - 27 batches submitted to accumulate stats from 1728 documents (-17126 virtual)
# 2025-09-25 20:58:17,249 - gensim.topic_coherence.text_analysis - INFO - 32 batches submitted to accumulate stats from 2048 documents (-17852 virtual)
# 2025-09-25 20:58:17,442 - gensim.topic_coherence.text_analysis - INFO - 35 batches submitted to accumulate stats from 2240 documents (-18476 virtual)
# 2025-09-25 20:58:17,532 - gensim.topic_coherence.text_analysis - INFO - 37 batches submitted to accumulate stats from 2368 documents (-16867 virtual)
# 2025-09-25 20:58:17,565 - gensim.topic_coherence.text_analysis - INFO - 38 batches submitted to accumulate stats from 2432 documents (-10635 virtual)
# 2025-09-25 20:58:17,589 - gensim.topic_coherence.text_analysis - INFO - 39 batches submitted to accumulate stats from 2496 documents (-10502 virtual)
# 2025-09-25 20:58:17,825 - gensim.topic_coherence.text_analysis - INFO - 42 batches submitted to accumulate stats from 2688 documents (-8460 virtual)
# 2025-09-25 20:58:17,847 - gensim.topic_coherence.text_analysis - INFO - 43 batches submitted to accumulate stats from 2752 documents (-7831 virtual)
# 2025-09-25 20:58:17,927 - gensim.topic_coherence.text_analysis - INFO - 44 batches submitted to accumulate stats from 2816 documents (-5691 virtual)
# 2025-09-25 20:58:18,084 - gensim.topic_coherence.text_analysis - INFO - 46 batches submitted to accumulate stats from 2944 documents (4168 virtual)
# 2025-09-25 20:58:18,143 - gensim.topic_coherence.text_analysis - INFO - 47 batches submitted to accumulate stats from 3008 documents (6003 virtual)
# 2025-09-25 20:58:18,214 - gensim.topic_coherence.text_analysis - INFO - 49 batches submitted to accumulate stats from 3136 documents (8539 virtual)
# 2025-09-25 20:58:19,850 - gensim.topic_coherence.text_analysis - INFO - 7 accumulators retrieved from output queue
# 2025-09-25 20:58:19,890 - gensim.topic_coherence.text_analysis - INFO - accumulated word occurrence stats for 136562 virtual documents
# 2025-09-25 20:58:20,435 - root - ERROR - 导出失败，错误：Cannot save file into a non-existent directory: '/Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search'
# 2025-09-25 20:58:20,435 - root - INFO - 本次训练完成。原主题数: 104，合并后超主题数: 98，C_V 一致性: 0.6469
# 2025-09-25 20:58:20,435 - root - INFO - 指标：轮廓系数 (合并前/后): 0.3317/0.3178, 离群率: 0.0068
# 正在进行参数组合训练: 100%|██████████| 64/64 [47:27<00:00, 44.50s/it]

# %% [markdown]
# ### 导出训练结果

# %%
results_df = pd.DataFrame(results)
print("\n--- 所有训练结果 ---")
print(results_df)

best_result = results_df.sort_values(by='cv_coherence', ascending=False).iloc[0]
print("\n--- C_V 一致性最佳参数组合 ---")
print(best_result)

results_df.to_excel(EXPORT_PATH, index=False)
logging.info(f"结果已导出至 {EXPORT_PATH}")
# Out:
# 2025-09-25 20:58:46,100 - root - INFO - 结果已导出至 /Users/hemengya/Desktop/数字贸易规则新版/第五版/output/grid_search.xlsx
# --- 所有训练结果 ---
#     n_neighbors  n_components  min_cluster_size  num_original_topics  \
# 0            10             5                 2                  197
# 1            10             5                 3                  153
# 2            10             5                 4                  138
# 3            10             5                 5                  124
# 4            10            10                 2                  190
# ..          ...           ...               ...                  ...
# 59           25            15                 5                   98
# 60           25            20                 2                  165
# 61           25            20                 3                  138
# 62           25            20                 4                  121
# 63           25            20                 5                  104
#
#     num_merged_topics  cv_coherence  intra_mean_before  silhouette_before  \
# 0                 179      0.607182           0.844138           0.361562
# 1                 139      0.625619           0.829410           0.340447
# 2                 124      0.636157           0.824287           0.333327
# 3                 110      0.638810           0.820408           0.298202
# 4                 172      0.613398           0.842452           0.365825
# ..                ...           ...                ...                ...
# 59                 91      0.639973           0.808016           0.294887
# 60                144      0.625517           0.831569           0.336974
# 61                124      0.633730           0.826855           0.323664
# 62                113      0.637429           0.824057           0.357762
# 63                 98      0.646923           0.819308           0.331744
#
#     outlier_rate_before  intra_mean_after  silhouette_after  \
# 0              0.212450          0.832402          0.348811
# 1              0.179622          0.825193          0.337849
# 2              0.163208          0.816707          0.337395
# 3              0.134097          0.813060          0.316719
# 4              0.239703          0.836785          0.356607
# ..                  ...               ...               ...
# 59             0.192010          0.797591          0.279676
# 60             0.339734          0.822367          0.335961
# 61             0.249613          0.817758          0.328070
# 62             0.204398          0.812476          0.339401
# 63             0.195417          0.805480          0.317757
#
#     outlier_rate_after
# 0             0.004955
# 1             0.004955
# 2             0.004336
# 3             0.003407
# 4             0.003716
# ..                 ...
# 59            0.007742
# 60            0.004026
# 61            0.004336
# 62            0.005265
# 63            0.006813
#
# [64 rows x 12 columns]
#
# --- C_V 一致性最佳参数组合 ---
# n_neighbors             25.000000
# n_components            20.000000
# min_cluster_size         5.000000
# num_original_topics    104.000000
# num_merged_topics       98.000000
# cv_coherence             0.646923
# intra_mean_before        0.819308
# silhouette_before        0.331744
# outlier_rate_before      0.195417
# intra_mean_after         0.805480
# silhouette_after         0.317757
# outlier_rate_after       0.006813
# Name: 63, dtype: float64
